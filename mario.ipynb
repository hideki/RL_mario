# %%
from nes_py.wrappers import JoypadSpace
import gym_super_mario_bros
from gym_super_mario_bros.actions import SIMPLE_MOVEMENT
env = gym_super_mario_bros.make('SuperMarioBros-v0')
env = JoypadSpace(env, SIMPLE_MOVEMENT)

done = True
for step in range(5000):
    if done:
        state = env.reset()
    state, reward, done, info = env.step(env.action_space.sample())
    env.render()

env.close()
# Out:
# /Users/hideki/miniconda3/envs/mario/lib/python3.8/site-packages/gym/envs/registration.py:505: UserWarning: WARN: The environment SuperMarioBros-v0 is out of date. You should consider upgrading to version `v3` with the environment ID `SuperMarioBros-v3`.
#   logger.warn(

# %% [markdown]
# ## 1. Setup Mario

# %%
# Import the game
import gym_super_mario_bros
# Import the Joypad wrapper
from nes_py.wrappers import JoypadSpace
# Import the SIMPLIFIED controls
from gym_super_mario_bros.actions import SIMPLE_MOVEMENT

# %%
# Setup game
env = gym_super_mario_bros.make('SuperMarioBros-v0')
env = JoypadSpace(env, SIMPLE_MOVEMENT)

# %%
# Create a flag - restart or not
done = True
# Loop through each frame in the game
for step in range(100000): 
    # Start the game to begin with 
    if done: 
        # Start the gamee
        env.reset()
    # Do random actions
    state, reward, done, info = env.step(env.action_space.sample())
    # Show the game on the screen
    env.render()
# Close the game
env.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 12
#      10     state, reward, done, info = env.step(env.action_space.sample())
#      11     # Show the game on the screen
# ---> 12     env.render()
#      13 # Close the game
#      14 env.close()
#
# File ~/miniconda3/envs/mario/lib/python3.8/site-packages/gym/core.py:286, in Wrapper.render(self, mode, **kwargs)
#     285 def render(self, mode="human", **kwargs):
# --> 286     return self.env.render(mode, **kwargs)
#
# File ~/miniconda3/envs/mario/lib/python3.8/site-packages/gym/core.py:286, in Wrapper.render(self, mode, **kwargs)
#     285 def render(self, mode="human", **kwargs):
# --> 286     return self.env.render(mode, **kwargs)
#
# File ~/miniconda3/envs/mario/lib/python3.8/site-packages/gym/core.py:286, in Wrapper.render(self, mode, **kwargs)
#     285 def render(self, mode="human", **kwargs):
# --> 286     return self.env.render(mode, **kwargs)
#
# File ~/miniconda3/envs/mario/lib/python3.8/site-packages/nes_py/nes_env.py:386, in NESEnv.render(self, mode)
#     380         self.viewer = ImageViewer(
#     381             caption=caption,
#     382             height=SCREEN_HEIGHT,
#     383             width=SCREEN_WIDTH,
#     384         )
#     385     # show the screen on the image viewer
# --> 386     self.viewer.show(self.screen)
#     387 elif mode == 'rgb_array':
#     388     return self.screen
#
# File ~/miniconda3/envs/mario/lib/python3.8/site-packages/nes_py/_image_viewer.py:138, in ImageViewer.show(self, frame)
#     136 self._window.clear()
#     137 self._window.switch_to()
# --> 138 self._window.dispatch_events()
#     139 # create an image data object
#     140 image = self.pyglet.image.ImageData(
#     141     frame.shape[1],
#     142     frame.shape[0],
#    (...)
#     145     pitch=frame.shape[1]*-3
#     146 )
#
# File ~/miniconda3/envs/mario/lib/python3.8/site-packages/pyglet/window/cocoa/__init__.py:308, in CocoaWindow.dispatch_events(self)
#     306 NSApp = NSApplication.sharedApplication()
#     307 while event and self._nswindow and self._context:
# --> 308     event = NSApp.nextEventMatchingMask_untilDate_inMode_dequeue_(
#     309         cocoapy.NSAnyEventMask, None, cocoapy.NSEventTrackingRunLoopMode, True)
#     311     if event:
#     312         event_type = event.type()
#
# File ~/miniconda3/envs/mario/lib/python3.8/site-packages/pyglet/libs/darwin/cocoapy/runtime.py:805, in ObjCBoundMethod.__call__(self, *args)
#     803 def __call__(self, *args):
#     804     """Call the method with the given arguments."""
# --> 805     return self.method(self.objc_id, *args)
#
# File ~/miniconda3/envs/mario/lib/python3.8/site-packages/pyglet/libs/darwin/cocoapy/runtime.py:775, in ObjCMethod.__call__(self, objc_id, *args)
#     773 f = self.get_callable()
#     774 try:
# --> 775     result = f(objc_id, self.selector, *args)
#     776     # Convert result to python type if it is a instance or class pointer.
#     777     if self.restype == ObjCInstance:
#
# KeyboardInterrupt:

# %% [markdown]
# ## 2. Preprocess Environment

# %%
# Install pytorch
# !pip3 install --pre torch torchvision torchaudio --index-url https://download.pytorch.org/whl/nightly/cpu
# Out:
# Looking in indexes: https://download.pytorch.org/whl/nightly/cpu
# Requirement already satisfied: torch in /Users/hideki/miniconda3/envs/mario/lib/python3.8/site-packages (2.5.0.dev20240729)
# Requirement already satisfied: torchvision in /Users/hideki/miniconda3/envs/mario/lib/python3.8/site-packages (0.20.0.dev20240729)
# Requirement already satisfied: torchaudio in /Users/hideki/miniconda3/envs/mario/lib/python3.8/site-packages (2.4.0.dev20240729)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/hideki/miniconda3/envs/mario/lib/python3.8/site-packages (from torch) (4.11.0)
# Requirement already satisfied: sympy==1.12.1 in /Users/hideki/miniconda3/envs/mario/lib/python3.8/site-packages (from torch) (1.12.1)
# Requirement already satisfied: jinja2 in /Users/hideki/miniconda3/envs/mario/lib/python3.8/site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /Users/hideki/miniconda3/envs/mario/lib/python3.8/site-packages (from torch) (2024.6.1)
# Requirement already satisfied: networkx in /Users/hideki/miniconda3/envs/mario/lib/python3.8/site-packages (from torch) (3.0rc1)
# Requirement already satisfied: filelock in /Users/hideki/miniconda3/envs/mario/lib/python3.8/site-packages (from torch) (3.13.1)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /Users/hideki/miniconda3/envs/mario/lib/python3.8/site-packages (from sympy==1.12.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /Users/hideki/miniconda3/envs/mario/lib/python3.8/site-packages (from torchvision) (1.24.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/hideki/miniconda3/envs/mario/lib/python3.8/site-packages (from torchvision) (9.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/hideki/miniconda3/envs/mario/lib/python3.8/site-packages (from jinja2->torch) (2.1.3)

# %%
import torch
if torch.backends.mps.is_available():
    mps_device = torch.device("mps")
    x = torch.ones(1, device=mps_device)
    print (x)
else:
    print ("MPS device not found.")
# Out:
# tensor([1.], device='mps:0')

# %%
# Import Frame Stacker Wrapper and GrayScaling Wrapper
from gym.wrappers import GrayScaleObservation
# Import Vectorization Wrappers
from stable_baselines3.common.vec_env import VecFrameStack, DummyVecEnv
# Import Matplotlib to show the impact of frame stacking
from matplotlib import pyplot as plt

# %%
# 1. Create the base environment
env = gym_super_mario_bros.make('SuperMarioBros-v0')
# 2. Simplify the controls 
env = JoypadSpace(env, SIMPLE_MOVEMENT)
# 3. Grayscale
env = GrayScaleObservation(env, keep_dim=True)
# 4. Wrap inside the Dummy Environment
env = DummyVecEnv([lambda: env])
# 5. Stack the frames
env = VecFrameStack(env, 4, channels_order='last')

# %%
state = env.reset()

# %%
state, reward, done, info = env.step([5])

# %%
plt.figure(figsize=(20,16))
for idx in range(state.shape[3]):
    plt.subplot(1,4,idx+1)
    plt.imshow(state[0][:,:,idx])
plt.show()

# %% [markdown]
# ## 3. Train the RL Model

# %%
# Import os for file path management
import os 
# Import PPO for algos
from stable_baselines3 import PPO
# Import Base Callback for saving models
from stable_baselines3.common.callbacks import BaseCallback

# %%
class TrainAndLoggingCallback(BaseCallback):

    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path

    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'best_model_{}'.format(self.n_calls))
            self.model.save(model_path)

        return True

# %%
CHECKPOINT_DIR = './train/'
LOG_DIR = './logs/'

# %%
# Setup model saving callback
callback = TrainAndLoggingCallback(check_freq=10000, save_path=CHECKPOINT_DIR)

# %%
# This is the AI model started
model = PPO('CnnPolicy', env, verbose=1, tensorboard_log=LOG_DIR, learning_rate=0.000001, 
            n_steps=512, device = "mps")
# Out:
# Using mps device
# Wrapping the env in a VecTransposeImage.

# %%
# Train the AI model, this is where the AI model starts to learn
model.learn(total_timesteps=1000000, callback=callback)
# Out:
# Logging to ./logs/PPO_1
# /Users/hideki/miniconda3/envs/mario/lib/python3.8/site-packages/gym_super_mario_bros/smb_env.py:148: RuntimeWarning: overflow encountered in scalar subtract
#   return (self.ram[0x86] - self.ram[0x071c]) % 256
# ----------------------------
# | time/              |     |
# |    fps             | 54  |
# |    iterations      | 1   |
# |    time_elapsed    | 9   |
# |    total_timesteps | 512 |
# ----------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 35            |
# |    iterations           | 2             |
# |    time_elapsed         | 29            |
# |    total_timesteps      | 1024          |
# | train/                  |               |
# |    approx_kl            | 2.8810347e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.000604      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 83.7          |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -3.96e-05     |
# |    value_loss           | 277           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 39            |
# |    iterations           | 3             |
# |    time_elapsed         | 38            |
# |    total_timesteps      | 1536          |
# | train/                  |               |
# |    approx_kl            | 5.1389332e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.0425        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0937        |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.000415     |
# |    value_loss           | 3.22          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 41            |
# |    iterations           | 4             |
# |    time_elapsed         | 48            |
# |    total_timesteps      | 2048          |
# | train/                  |               |
# |    approx_kl            | 1.7856364e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.017         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.137         |
# |    n_updates            | 30            |
# |    policy_gradient_loss | -0.000173     |
# |    value_loss           | 1.25          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 43            |
# |    iterations           | 5             |
# |    time_elapsed         | 58            |
# |    total_timesteps      | 2560          |
# | train/                  |               |
# |    approx_kl            | 1.4889403e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.00791      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.229         |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -0.000157     |
# |    value_loss           | 1.1           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 44            |
# |    iterations           | 6             |
# |    time_elapsed         | 68            |
# |    total_timesteps      | 3072          |
# | train/                  |               |
# |    approx_kl            | 1.2591248e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.0066       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.088         |
# |    n_updates            | 50            |
# |    policy_gradient_loss | -0.000157     |
# |    value_loss           | 0.564         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 45            |
# |    iterations           | 7             |
# |    time_elapsed         | 78            |
# |    total_timesteps      | 3584          |
# | train/                  |               |
# |    approx_kl            | 1.0647345e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.00392      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.112         |
# |    n_updates            | 60            |
# |    policy_gradient_loss | -0.000129     |
# |    value_loss           | 0.547         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 46           |
# |    iterations           | 8            |
# |    time_elapsed         | 88           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 7.538474e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | -0.00206     |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.107        |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -6.11e-05    |
# |    value_loss           | 0.415        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 46            |
# |    iterations           | 9             |
# |    time_elapsed         | 98            |
# |    total_timesteps      | 4608          |
# | train/                  |               |
# |    approx_kl            | 5.6104036e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.00462       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.109         |
# |    n_updates            | 80            |
# |    policy_gradient_loss | -8e-05        |
# |    value_loss           | 0.409         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 47           |
# |    iterations           | 10           |
# |    time_elapsed         | 107          |
# |    total_timesteps      | 5120         |
# | train/                  |              |
# |    approx_kl            | 9.517185e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | 0.00236      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0905       |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00011     |
# |    value_loss           | 0.266        |
# ------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 47             |
# |    iterations           | 11             |
# |    time_elapsed         | 118            |
# |    total_timesteps      | 5632           |
# | train/                  |                |
# |    approx_kl            | 1.43941725e-05 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.95          |
# |    explained_variance   | 0.00244        |
# |    learning_rate        | 1e-06          |
# |    loss                 | 0.0455         |
# |    n_updates            | 100            |
# |    policy_gradient_loss | -0.000194      |
# |    value_loss           | 0.196          |
# --------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 47            |
# |    iterations           | 12            |
# |    time_elapsed         | 128           |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 1.5512807e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.00256       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0887        |
# |    n_updates            | 110           |
# |    policy_gradient_loss | -0.000202     |
# |    value_loss           | 0.229         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 47            |
# |    iterations           | 13            |
# |    time_elapsed         | 139           |
# |    total_timesteps      | 6656          |
# | train/                  |               |
# |    approx_kl            | 2.1289103e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.0192       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0843        |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -0.000446     |
# |    value_loss           | 0.722         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 48            |
# |    iterations           | 14            |
# |    time_elapsed         | 149           |
# |    total_timesteps      | 7168          |
# | train/                  |               |
# |    approx_kl            | 1.7756829e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.00368       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.207         |
# |    n_updates            | 130           |
# |    policy_gradient_loss | -0.000259     |
# |    value_loss           | 0.57          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 48            |
# |    iterations           | 15            |
# |    time_elapsed         | 159           |
# |    total_timesteps      | 7680          |
# | train/                  |               |
# |    approx_kl            | 4.6471367e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.0114       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0839        |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -0.000824     |
# |    value_loss           | 0.284         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 48            |
# |    iterations           | 16            |
# |    time_elapsed         | 169           |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 1.7244834e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.00999       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.101         |
# |    n_updates            | 150           |
# |    policy_gradient_loss | -0.000255     |
# |    value_loss           | 0.171         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 48            |
# |    iterations           | 17            |
# |    time_elapsed         | 179           |
# |    total_timesteps      | 8704          |
# | train/                  |               |
# |    approx_kl            | 3.1236676e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.0119        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 131           |
# |    n_updates            | 160           |
# |    policy_gradient_loss | -0.000237     |
# |    value_loss           | 325           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 48            |
# |    iterations           | 18            |
# |    time_elapsed         | 189           |
# |    total_timesteps      | 9216          |
# | train/                  |               |
# |    approx_kl            | 1.5498605e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.0152        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 63.8          |
# |    n_updates            | 170           |
# |    policy_gradient_loss | -0.000229     |
# |    value_loss           | 140           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 48            |
# |    iterations           | 19            |
# |    time_elapsed         | 199           |
# |    total_timesteps      | 9728          |
# | train/                  |               |
# |    approx_kl            | 2.5433954e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0243        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 13.7          |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -0.000223     |
# |    value_loss           | 18.8          |
# -------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 48             |
# |    iterations           | 20             |
# |    time_elapsed         | 209            |
# |    total_timesteps      | 10240          |
# | train/                  |                |
# |    approx_kl            | 0.000100416015 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.94          |
# |    explained_variance   | 0.0268         |
# |    learning_rate        | 1e-06          |
# |    loss                 | 226            |
# |    n_updates            | 190            |
# |    policy_gradient_loss | 0.00027        |
# |    value_loss           | 575            |
# --------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 48           |
# |    iterations           | 21           |
# |    time_elapsed         | 219          |
# |    total_timesteps      | 10752        |
# | train/                  |              |
# |    approx_kl            | 4.679244e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.00691      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.361        |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.000131    |
# |    value_loss           | 7.01         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 49           |
# |    iterations           | 22           |
# |    time_elapsed         | 229          |
# |    total_timesteps      | 11264        |
# | train/                  |              |
# |    approx_kl            | 9.195518e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.087        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.31         |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.000502    |
# |    value_loss           | 3.9          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 49           |
# |    iterations           | 23           |
# |    time_elapsed         | 239          |
# |    total_timesteps      | 11776        |
# | train/                  |              |
# |    approx_kl            | 5.039631e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.00432      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.191        |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -8.43e-05    |
# |    value_loss           | 1.97         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 49            |
# |    iterations           | 24            |
# |    time_elapsed         | 250           |
# |    total_timesteps      | 12288         |
# | train/                  |               |
# |    approx_kl            | 3.4727855e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0394        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.249         |
# |    n_updates            | 230           |
# |    policy_gradient_loss | -0.00017      |
# |    value_loss           | 1.79          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 49           |
# |    iterations           | 25           |
# |    time_elapsed         | 260          |
# |    total_timesteps      | 12800        |
# | train/                  |              |
# |    approx_kl            | 6.361748e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | -0.263       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.282        |
# |    n_updates            | 240          |
# |    policy_gradient_loss | 0.000196     |
# |    value_loss           | 1.24         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 49            |
# |    iterations           | 26            |
# |    time_elapsed         | 270           |
# |    total_timesteps      | 13312         |
# | train/                  |               |
# |    approx_kl            | 1.8263701e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.00392       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.185         |
# |    n_updates            | 250           |
# |    policy_gradient_loss | -8.89e-05     |
# |    value_loss           | 0.906         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 49            |
# |    iterations           | 27            |
# |    time_elapsed         | 280           |
# |    total_timesteps      | 13824         |
# | train/                  |               |
# |    approx_kl            | 1.4713616e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.00222       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.219         |
# |    n_updates            | 260           |
# |    policy_gradient_loss | -0.000142     |
# |    value_loss           | 0.731         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 49            |
# |    iterations           | 28            |
# |    time_elapsed         | 290           |
# |    total_timesteps      | 14336         |
# | train/                  |               |
# |    approx_kl            | 3.6512385e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.00868       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.165         |
# |    n_updates            | 270           |
# |    policy_gradient_loss | -0.00048      |
# |    value_loss           | 0.426         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 49            |
# |    iterations           | 29            |
# |    time_elapsed         | 300           |
# |    total_timesteps      | 14848         |
# | train/                  |               |
# |    approx_kl            | 2.7127215e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.00691      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.11          |
# |    n_updates            | 280           |
# |    policy_gradient_loss | -0.000205     |
# |    value_loss           | 0.392         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 49           |
# |    iterations           | 30           |
# |    time_elapsed         | 310          |
# |    total_timesteps      | 15360        |
# | train/                  |              |
# |    approx_kl            | 1.914124e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | -0.00556     |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.223        |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.000336    |
# |    value_loss           | 0.532        |
# ------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 49             |
# |    iterations           | 31             |
# |    time_elapsed         | 320            |
# |    total_timesteps      | 15872          |
# | train/                  |                |
# |    approx_kl            | 1.27897365e-05 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.94          |
# |    explained_variance   | 0.00629        |
# |    learning_rate        | 1e-06          |
# |    loss                 | 0.0754         |
# |    n_updates            | 300            |
# |    policy_gradient_loss | -0.000144      |
# |    value_loss           | 0.224          |
# --------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 49            |
# |    iterations           | 32            |
# |    time_elapsed         | 330           |
# |    total_timesteps      | 16384         |
# | train/                  |               |
# |    approx_kl            | 1.2066797e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0124        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0886        |
# |    n_updates            | 310           |
# |    policy_gradient_loss | -0.000117     |
# |    value_loss           | 0.239         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 49            |
# |    iterations           | 33            |
# |    time_elapsed         | 339           |
# |    total_timesteps      | 16896         |
# | train/                  |               |
# |    approx_kl            | 5.1524956e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.00323      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.1           |
# |    n_updates            | 320           |
# |    policy_gradient_loss | -0.000506     |
# |    value_loss           | 0.196         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 49            |
# |    iterations           | 34            |
# |    time_elapsed         | 349           |
# |    total_timesteps      | 17408         |
# | train/                  |               |
# |    approx_kl            | 3.9099017e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0262        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.126         |
# |    n_updates            | 330           |
# |    policy_gradient_loss | -0.000471     |
# |    value_loss           | 0.267         |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 49          |
# |    iterations           | 35          |
# |    time_elapsed         | 359         |
# |    total_timesteps      | 17920       |
# | train/                  |             |
# |    approx_kl            | 7.83836e-05 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.94       |
# |    explained_variance   | 0.0701      |
# |    learning_rate        | 1e-06       |
# |    loss                 | 81.8        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | 0.000229    |
# |    value_loss           | 171         |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 49            |
# |    iterations           | 36            |
# |    time_elapsed         | 369           |
# |    total_timesteps      | 18432         |
# | train/                  |               |
# |    approx_kl            | 0.00016452745 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0912        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 74.5          |
# |    n_updates            | 350           |
# |    policy_gradient_loss | 0.000351      |
# |    value_loss           | 192           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 49           |
# |    iterations           | 37           |
# |    time_elapsed         | 379          |
# |    total_timesteps      | 18944        |
# | train/                  |              |
# |    approx_kl            | 5.381019e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.542        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.156        |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.000212    |
# |    value_loss           | 1.19         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 50           |
# |    iterations           | 38           |
# |    time_elapsed         | 389          |
# |    total_timesteps      | 19456        |
# | train/                  |              |
# |    approx_kl            | 3.110338e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.216        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0679       |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00016     |
# |    value_loss           | 1            |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 50            |
# |    iterations           | 39            |
# |    time_elapsed         | 398           |
# |    total_timesteps      | 19968         |
# | train/                  |               |
# |    approx_kl            | 2.3723813e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0822        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0999        |
# |    n_updates            | 380           |
# |    policy_gradient_loss | -0.000117     |
# |    value_loss           | 0.769         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 50            |
# |    iterations           | 40            |
# |    time_elapsed         | 409           |
# |    total_timesteps      | 20480         |
# | train/                  |               |
# |    approx_kl            | 3.6496203e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.042         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.096         |
# |    n_updates            | 390           |
# |    policy_gradient_loss | -0.000361     |
# |    value_loss           | 0.535         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 50            |
# |    iterations           | 41            |
# |    time_elapsed         | 419           |
# |    total_timesteps      | 20992         |
# | train/                  |               |
# |    approx_kl            | 2.7488917e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.0084       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0845        |
# |    n_updates            | 400           |
# |    policy_gradient_loss | -0.000187     |
# |    value_loss           | 0.495         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 50            |
# |    iterations           | 42            |
# |    time_elapsed         | 429           |
# |    total_timesteps      | 21504         |
# | train/                  |               |
# |    approx_kl            | 2.9339688e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.059         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.149         |
# |    n_updates            | 410           |
# |    policy_gradient_loss | -0.000223     |
# |    value_loss           | 0.369         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 49            |
# |    iterations           | 43            |
# |    time_elapsed         | 440           |
# |    total_timesteps      | 22016         |
# | train/                  |               |
# |    approx_kl            | 2.3916247e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0989        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0941        |
# |    n_updates            | 420           |
# |    policy_gradient_loss | -0.000249     |
# |    value_loss           | 0.241         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 49            |
# |    iterations           | 44            |
# |    time_elapsed         | 451           |
# |    total_timesteps      | 22528         |
# | train/                  |               |
# |    approx_kl            | 1.0069809e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.659         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0835        |
# |    n_updates            | 430           |
# |    policy_gradient_loss | -5.43e-05     |
# |    value_loss           | 0.286         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 49            |
# |    iterations           | 45            |
# |    time_elapsed         | 461           |
# |    total_timesteps      | 23040         |
# | train/                  |               |
# |    approx_kl            | 4.0932442e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0185        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0596        |
# |    n_updates            | 440           |
# |    policy_gradient_loss | -0.000432     |
# |    value_loss           | 0.149         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 49           |
# |    iterations           | 46           |
# |    time_elapsed         | 471          |
# |    total_timesteps      | 23552        |
# | train/                  |              |
# |    approx_kl            | 5.821907e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | -0.0245      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.043        |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.000632    |
# |    value_loss           | 0.126        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 49            |
# |    iterations           | 47            |
# |    time_elapsed         | 481           |
# |    total_timesteps      | 24064         |
# | train/                  |               |
# |    approx_kl            | 5.7724537e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.00924       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.195         |
# |    n_updates            | 460           |
# |    policy_gradient_loss | -3.51e-05     |
# |    value_loss           | 0.277         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 49            |
# |    iterations           | 48            |
# |    time_elapsed         | 492           |
# |    total_timesteps      | 24576         |
# | train/                  |               |
# |    approx_kl            | 3.2771146e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.00236      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0678        |
# |    n_updates            | 470           |
# |    policy_gradient_loss | -0.00026      |
# |    value_loss           | 0.148         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 49           |
# |    iterations           | 49           |
# |    time_elapsed         | 502          |
# |    total_timesteps      | 25088        |
# | train/                  |              |
# |    approx_kl            | 3.215007e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.00589      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0665       |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.000331    |
# |    value_loss           | 0.149        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 49           |
# |    iterations           | 50           |
# |    time_elapsed         | 512          |
# |    total_timesteps      | 25600        |
# | train/                  |              |
# |    approx_kl            | 6.607594e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.00361      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0493       |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.000839    |
# |    value_loss           | 0.105        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 49           |
# |    iterations           | 51           |
# |    time_elapsed         | 522          |
# |    total_timesteps      | 26112        |
# | train/                  |              |
# |    approx_kl            | 0.0004635955 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.93        |
# |    explained_variance   | 0.117        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 156          |
# |    n_updates            | 500          |
# |    policy_gradient_loss | 7.31e-05     |
# |    value_loss           | 409          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 49            |
# |    iterations           | 52            |
# |    time_elapsed         | 532           |
# |    total_timesteps      | 26624         |
# | train/                  |               |
# |    approx_kl            | 5.5780518e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.215         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.179         |
# |    n_updates            | 510           |
# |    policy_gradient_loss | -0.000235     |
# |    value_loss           | 1.76          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 49            |
# |    iterations           | 53            |
# |    time_elapsed         | 544           |
# |    total_timesteps      | 27136         |
# | train/                  |               |
# |    approx_kl            | 4.8664515e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.0497        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.274         |
# |    n_updates            | 520           |
# |    policy_gradient_loss | -4.44e-05     |
# |    value_loss           | 0.982         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 49            |
# |    iterations           | 54            |
# |    time_elapsed         | 555           |
# |    total_timesteps      | 27648         |
# | train/                  |               |
# |    approx_kl            | 2.5349553e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.455         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.124         |
# |    n_updates            | 530           |
# |    policy_gradient_loss | -0.000125     |
# |    value_loss           | 0.532         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 49           |
# |    iterations           | 55           |
# |    time_elapsed         | 565          |
# |    total_timesteps      | 28160        |
# | train/                  |              |
# |    approx_kl            | 3.000989e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.93        |
# |    explained_variance   | 0.183        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.265        |
# |    n_updates            | 540          |
# |    policy_gradient_loss | -0.000273    |
# |    value_loss           | 0.529        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 49            |
# |    iterations           | 56            |
# |    time_elapsed         | 576           |
# |    total_timesteps      | 28672         |
# | train/                  |               |
# |    approx_kl            | 1.2647128e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.0701        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.106         |
# |    n_updates            | 550           |
# |    policy_gradient_loss | -2.63e-05     |
# |    value_loss           | 0.395         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 49            |
# |    iterations           | 57            |
# |    time_elapsed         | 586           |
# |    total_timesteps      | 29184         |
# | train/                  |               |
# |    approx_kl            | 1.3323966e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.00102       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.142         |
# |    n_updates            | 560           |
# |    policy_gradient_loss | 7.61e-06      |
# |    value_loss           | 0.428         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 49            |
# |    iterations           | 58            |
# |    time_elapsed         | 596           |
# |    total_timesteps      | 29696         |
# | train/                  |               |
# |    approx_kl            | 2.3738248e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.00542       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.101         |
# |    n_updates            | 570           |
# |    policy_gradient_loss | -0.000128     |
# |    value_loss           | 0.301         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 49           |
# |    iterations           | 59           |
# |    time_elapsed         | 607          |
# |    total_timesteps      | 30208        |
# | train/                  |              |
# |    approx_kl            | 3.839645e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.93        |
# |    explained_variance   | 0.0653       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.134        |
# |    n_updates            | 580          |
# |    policy_gradient_loss | -0.000282    |
# |    value_loss           | 0.273        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 49            |
# |    iterations           | 60            |
# |    time_elapsed         | 621           |
# |    total_timesteps      | 30720         |
# | train/                  |               |
# |    approx_kl            | 1.4066929e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.0141        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.134         |
# |    n_updates            | 590           |
# |    policy_gradient_loss | -7.72e-05     |
# |    value_loss           | 0.325         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 49            |
# |    iterations           | 61            |
# |    time_elapsed         | 631           |
# |    total_timesteps      | 31232         |
# | train/                  |               |
# |    approx_kl            | 2.2510882e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | -0.00358      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.143         |
# |    n_updates            | 600           |
# |    policy_gradient_loss | -0.000211     |
# |    value_loss           | 0.251         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 49           |
# |    iterations           | 62           |
# |    time_elapsed         | 641          |
# |    total_timesteps      | 31744        |
# ...
# |    entropy_loss         | -0.254        |
# |    explained_variance   | 0.326         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 289           |
# |    n_updates            | 19330         |
# |    policy_gradient_loss | -4.62e-05     |
# |    value_loss           | 1.18e+03      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 55           |
# |    iterations           | 1935         |
# |    time_elapsed         | 17793        |
# |    total_timesteps      | 990720       |
# | train/                  |              |
# |    approx_kl            | 0.0010013571 |
# |    clip_fraction        | 0.0158       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.279       |
# |    explained_variance   | 0.865        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 78.9         |
# |    n_updates            | 19340        |
# |    policy_gradient_loss | -0.00104     |
# |    value_loss           | 203          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 55            |
# |    iterations           | 1936          |
# |    time_elapsed         | 17802         |
# |    total_timesteps      | 991232        |
# | train/                  |               |
# |    approx_kl            | 0.00018327881 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.279        |
# |    explained_variance   | 0.676         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 311           |
# |    n_updates            | 19350         |
# |    policy_gradient_loss | -0.000347     |
# |    value_loss           | 556           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 55           |
# |    iterations           | 1937         |
# |    time_elapsed         | 17811        |
# |    total_timesteps      | 991744       |
# | train/                  |              |
# |    approx_kl            | 0.0010752196 |
# |    clip_fraction        | 0.000977     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.251       |
# |    explained_variance   | 0.73         |
# |    learning_rate        | 1e-06        |
# |    loss                 | 56.8         |
# |    n_updates            | 19360        |
# |    policy_gradient_loss | -0.00095     |
# |    value_loss           | 144          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 55           |
# |    iterations           | 1938         |
# |    time_elapsed         | 17820        |
# |    total_timesteps      | 992256       |
# | train/                  |              |
# |    approx_kl            | 0.0010767431 |
# |    clip_fraction        | 0.00176      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.219       |
# |    explained_variance   | 0.671        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 405          |
# |    n_updates            | 19370        |
# |    policy_gradient_loss | -0.00136     |
# |    value_loss           | 640          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 55           |
# |    iterations           | 1939         |
# |    time_elapsed         | 17829        |
# |    total_timesteps      | 992768       |
# | train/                  |              |
# |    approx_kl            | 8.617295e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.195       |
# |    explained_variance   | 0.73         |
# |    learning_rate        | 1e-06        |
# |    loss                 | 162          |
# |    n_updates            | 19380        |
# |    policy_gradient_loss | 9.82e-05     |
# |    value_loss           | 299          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 55            |
# |    iterations           | 1940          |
# |    time_elapsed         | 17838         |
# |    total_timesteps      | 993280        |
# | train/                  |               |
# |    approx_kl            | 0.00030452933 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.214        |
# |    explained_variance   | 0.451         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 711           |
# |    n_updates            | 19390         |
# |    policy_gradient_loss | -0.000162     |
# |    value_loss           | 1e+03         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 55           |
# |    iterations           | 1941         |
# |    time_elapsed         | 17847        |
# |    total_timesteps      | 993792       |
# | train/                  |              |
# |    approx_kl            | 0.0009901403 |
# |    clip_fraction        | 0.017        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.246       |
# |    explained_variance   | 0.866        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 111          |
# |    n_updates            | 19400        |
# |    policy_gradient_loss | -0.00357     |
# |    value_loss           | 199          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 55          |
# |    iterations           | 1942        |
# |    time_elapsed         | 17856       |
# |    total_timesteps      | 994304      |
# | train/                  |             |
# |    approx_kl            | 0.001027984 |
# |    clip_fraction        | 0.00156     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.231      |
# |    explained_variance   | 0.845       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 234         |
# |    n_updates            | 19410       |
# |    policy_gradient_loss | -0.000592   |
# |    value_loss           | 429         |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 55            |
# |    iterations           | 1943          |
# |    time_elapsed         | 17866         |
# |    total_timesteps      | 994816        |
# | train/                  |               |
# |    approx_kl            | 0.00013407413 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.213        |
# |    explained_variance   | 0.72          |
# |    learning_rate        | 1e-06         |
# |    loss                 | 237           |
# |    n_updates            | 19420         |
# |    policy_gradient_loss | -0.000265     |
# |    value_loss           | 532           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 55            |
# |    iterations           | 1944          |
# |    time_elapsed         | 17875         |
# |    total_timesteps      | 995328        |
# | train/                  |               |
# |    approx_kl            | 0.00030582992 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.238        |
# |    explained_variance   | 0.502         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 216           |
# |    n_updates            | 19430         |
# |    policy_gradient_loss | -0.000636     |
# |    value_loss           | 644           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 55           |
# |    iterations           | 1945         |
# |    time_elapsed         | 17884        |
# |    total_timesteps      | 995840       |
# | train/                  |              |
# |    approx_kl            | 0.0003337072 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.243       |
# |    explained_variance   | 0.857        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 99.3         |
# |    n_updates            | 19440        |
# |    policy_gradient_loss | -0.000104    |
# |    value_loss           | 379          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 55            |
# |    iterations           | 1946          |
# |    time_elapsed         | 17893         |
# |    total_timesteps      | 996352        |
# | train/                  |               |
# |    approx_kl            | 0.00012232084 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.222        |
# |    explained_variance   | 0.361         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 407           |
# |    n_updates            | 19450         |
# |    policy_gradient_loss | -0.00113      |
# |    value_loss           | 936           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 55           |
# |    iterations           | 1947         |
# |    time_elapsed         | 17902        |
# |    total_timesteps      | 996864       |
# | train/                  |              |
# |    approx_kl            | 0.0001367256 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.229       |
# |    explained_variance   | 0.895        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 125          |
# |    n_updates            | 19460        |
# |    policy_gradient_loss | -0.000331    |
# |    value_loss           | 276          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 55            |
# |    iterations           | 1948          |
# |    time_elapsed         | 17911         |
# |    total_timesteps      | 997376        |
# | train/                  |               |
# |    approx_kl            | 0.00019241439 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.219        |
# |    explained_variance   | 0.519         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 200           |
# |    n_updates            | 19470         |
# |    policy_gradient_loss | -0.00028      |
# |    value_loss           | 1.03e+03      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 55           |
# |    iterations           | 1949         |
# |    time_elapsed         | 17920        |
# |    total_timesteps      | 997888       |
# | train/                  |              |
# |    approx_kl            | 0.0004001495 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.231       |
# |    explained_variance   | 0.642        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 192          |
# |    n_updates            | 19480        |
# |    policy_gradient_loss | -0.000601    |
# |    value_loss           | 482          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 55            |
# |    iterations           | 1950          |
# |    time_elapsed         | 17929         |
# |    total_timesteps      | 998400        |
# | train/                  |               |
# |    approx_kl            | 7.8127836e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.249        |
# |    explained_variance   | 0.785         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 113           |
# |    n_updates            | 19490         |
# |    policy_gradient_loss | -5.12e-05     |
# |    value_loss           | 232           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 55            |
# |    iterations           | 1951          |
# |    time_elapsed         | 17938         |
# |    total_timesteps      | 998912        |
# | train/                  |               |
# |    approx_kl            | 0.00010652107 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.235        |
# |    explained_variance   | 0.856         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 245           |
# |    n_updates            | 19500         |
# |    policy_gradient_loss | -0.000114     |
# |    value_loss           | 429           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 55           |
# |    iterations           | 1952         |
# |    time_elapsed         | 17947        |
# |    total_timesteps      | 999424       |
# | train/                  |              |
# |    approx_kl            | 0.0010677524 |
# |    clip_fraction        | 0.00957      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.245       |
# |    explained_variance   | 0.823        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 113          |
# |    n_updates            | 19510        |
# |    policy_gradient_loss | -0.00141     |
# |    value_loss           | 238          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 55            |
# |    iterations           | 1953          |
# |    time_elapsed         | 17956         |
# |    total_timesteps      | 999936        |
# | train/                  |               |
# |    approx_kl            | 6.9475034e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.265        |
# |    explained_variance   | 0.89          |
# |    learning_rate        | 1e-06         |
# |    loss                 | 87.9          |
# |    n_updates            | 19520         |
# |    policy_gradient_loss | -0.000253     |
# |    value_loss           | 212           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 55            |
# |    iterations           | 1954          |
# |    time_elapsed         | 17965         |
# |    total_timesteps      | 1000448       |
# | train/                  |               |
# |    approx_kl            | 0.00016264094 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.258        |
# |    explained_variance   | 0.816         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 95.4          |
# |    n_updates            | 19530         |
# |    policy_gradient_loss | -0.000191     |
# |    value_loss           | 218           |
# -------------------------------------------

# %%
model.save('thisisatestmodel')

# %%
## 4. Test it Out

# %%
# Load model
model = PPO.load('./train/best_model_1000000', device = "mps")
# Out:
# /Users/hideki/miniconda3/envs/mario/lib/python3.8/site-packages/stable_baselines3/common/save_util.py:435: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   th_object = th.load(file_content, map_location=device)

# %%
state = env.reset()

# %%
# Start the game 
state = env.reset()
done = False
# Loop through the game
while True: 
    if done:
        break
    action, _ = model.predict(state)
    state, reward, done, info = env.step(action)
    env.render()

env.close()
# Out:
# /Users/hideki/miniconda3/envs/mario/lib/python3.8/site-packages/gym_super_mario_bros/smb_env.py:148: RuntimeWarning: overflow encountered in scalar subtract
#   return (self.ram[0x86] - self.ram[0x071c]) % 256
